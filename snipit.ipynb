# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt

top200 = "datasets/Top200.csv"
topgenre = "datasets/Top10000genre.csv"

top200_df = pd.read_csv(top200)
topgenre_df = pd.read_csv(topgenre)


top200_df = top200_df.drop(columns=['Index','Song ID','Chord','Valence','Duration (ms)','Tempo','Liveness','Acousticness','Speechiness'])
topgenre_df = topgenre_df.drop(columns=['track_id','duration_ms','energy','instrumentalness','key','liveness','loudness','mode','speechiness','tempo','time_signature','valence'])
# genre = []
# genre = (pd.unique(topgenre_df['genre']))
# genre200 = []
# genre200 = (pd.unique(top200_df['Genre']))
# genre200

top200_df.columns
top200_df.Genre.value_counts()
# pop_genre = top200_df[top200_df['Genre'].str.contains('pop')]
# pop_genre = top200_df[(top200_df['Genre'].str.contains('pop')) & (top200_df['Genre'].str.len()<2)]
top200_df.Genre= top200_df.Genre.str.replace('[','')
top200_df.Genre= top200_df.Genre.str.replace(']','')
top200_df.Genre = top200_df.Genre.str.split(',')
top200_df = top200_df.explode('Genre')
top200_df.Genre = top200_df.Genre.str.replace("\'", "")

top200_df
# Out:
# /var/folders/tn/m51dm4nd5wv2rw2867yd_l_h0000gn/T/ipykernel_16837/73365268.py:25: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   top200_df.Genre= top200_df.Genre.str.replace('[','')
# /var/folders/tn/m51dm4nd5wv2rw2867yd_l_h0000gn/T/ipykernel_16837/73365268.py:26: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   top200_df.Genre= top200_df.Genre.str.replace(']','')
#       Highest Charting Position  Number of Times Charted  \
# 0                             1                        8
# 0                             1                        8
# 1                             2                        3
# 2                             1                       11
# 3                             3                        5
# ...                         ...                      ...
# 1553                        197                        1
# 1554                        198                        1
# 1554                        198                        1
# 1555                        199                        1
# 1555                        199                        1
#
#      Week of Highest Charting                           Song Name     Streams  \
# 0      2021-07-23--2021-07-30                             Beggin'  48,633,449
# 0      2021-07-23--2021-07-30                             Beggin'  48,633,449
# 1      2021-07-23--2021-07-30           STAY (with Justin Bieber)  47,248,719
# 2      2021-06-25--2021-07-02                            good 4 u  40,162,559
# 3      2021-07-02--2021-07-09                          Bad Habits  37,799,456
# ...                       ...                                 ...         ...
# 1553   2019-12-27--2020-01-03           Havana (feat. Young Thug)   4,620,876
# 1554   2019-12-27--2020-01-03          Surtada - Remix Brega Funk   4,607,385
# 1554   2019-12-27--2020-01-03          Surtada - Remix Brega Funk   4,607,385
# 1555   2019-12-27--2020-01-03  Lover (Remix) [feat. Shawn Mendes]   4,595,450
# 1555   2019-12-27--2020-01-03  Lover (Remix) [feat. Shawn Mendes]   4,595,450
#
#                              Artist Artist Followers                Genre  \
# 0                          Måneskin          3377762  indie rock italiano
# 0                          Måneskin          3377762          italian pop
# 1                     The Kid LAROI          2230022   australian hip hop
# 2                    Olivia Rodrigo          6266514                  pop
# 3                        Ed Sheeran         83293380                  pop
# ...                             ...              ...                  ...
# 1553                 Camila Cabello         22698747        post-teen pop
# 1554  Dadá Boladão, Tati Zaqui, OIK           208630           brega funk
# 1554  Dadá Boladão, Tati Zaqui, OIK           208630         funk carioca
# 1555                   Taylor Swift         42227614                  pop
# 1555                   Taylor Swift         42227614        post-teen pop
#
#      Release Date                                      Weeks Charted  \
# 0      2017-12-08  2021-07-23--2021-07-30\n2021-07-16--2021-07-23...
# 0      2017-12-08  2021-07-23--2021-07-30\n2021-07-16--2021-07-23...
# 1      2021-07-09  2021-07-23--2021-07-30\n2021-07-16--2021-07-23...
# 2      2021-05-21  2021-07-23--2021-07-30\n2021-07-16--2021-07-23...
# 3      2021-06-25  2021-07-23--2021-07-30\n2021-07-16--2021-07-23...
# ...           ...                                                ...
# 1553   2018-01-12                             2019-12-27--2020-01-03
# 1554   2019-09-25                             2019-12-27--2020-01-03
# 1554   2019-09-25                             2019-12-27--2020-01-03
# 1555   2019-11-13                             2019-12-27--2020-01-03
# 1555   2019-11-13                             2019-12-27--2020-01-03
#
#      Popularity Danceability Energy Loudness
# 0           100        0.714    0.8   -4.808
# 0           100        0.714    0.8   -4.808
# 1            99        0.591  0.764   -5.484
# 2            99        0.563  0.664   -5.044
# 3            98        0.808  0.897   -3.712
# ...         ...          ...    ...      ...
# 1553         81        0.765  0.523   -4.333
# 1554         60        0.832   0.55   -7.026
# 1554         60        0.832   0.55   -7.026
# 1555         70        0.448  0.603   -7.176
# 1555         70        0.448  0.603   -7.176
#
# [4665 rows x 14 columns]

# %%
top200_df['Genre']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/tn/m51dm4nd5wv2rw2867yd_l_h0000gn/T/ipykernel_16837/2647274526.py in <module>
# ----> 1 top200_df('Genre')
#
# TypeError: 'DataFrame' object is not callable
